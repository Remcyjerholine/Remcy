# %%
#madlib game
adjective1=input("enter a adjective")
noun1=input=("enter a noun")
adjective2=input("enter a adjective")
verb1=input("enter a verb")
adjective3=input("enter a adjective")

print(f"today i went to a {adjective1},")
print(f"in the exibit ,i saw a {noun1},")
print(f"the {noun1} was {adjective2} and{verb1}.")
print(f"i{adjective3} was truly ")
# Out:
# enter a adjective hgjg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 adjective1=input("enter a adjective")
#       3 noun1=input=("enter a noun")
# ----> 4 adjective2=input("enter a adjective")
#       5 verb1=input("enter a verb")
#       6 adjective3=input("enter a adjective")
#
# TypeError: 'str' object is not callable

# %%
weight=float(input("enter the weight:"))
unit=input("enter the unit(k or l):")
if unit=="k":
    weight=weight*2.205
elif  unit=="l"    :
    weight=weight/2.205
print(weight)
# Out:
# enter the weight: 23
# enter the unit(k or l): k
# 50.715

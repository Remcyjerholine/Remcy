# %%
#python calculator
operator=input("enter a operator(+,-,*,%,/):")
num1=float(input("enter the numer one:"))
num2=float(input("enter the numer one:"))
if operator == '+':
    result=num1+num2
    print(round(result,3))
elif operator =='-':
    reselu=num1-num2
    print(round(result,3))
elif operator =='*':
    result=num1*num2
    print(round(result,3))
elif operator =='/':
    result=num1/num2
    print(rouond(result,3))    
else:
    print("none")
# Out:
# enter a operator(+,-,*,%,/): +
# enter the numer one: 4
# enter the numer one: 5
# 9.0

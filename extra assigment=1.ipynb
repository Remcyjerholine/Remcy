# %%
a=int(input("a="))
b=int(input("b="))
add=a+b
print("add=",add)
# Out:
# a= 9
# b= 9
# add= 18

# %%
a=int(input("a="))
b=int(input("b="))
sub=a-b
print("add=",sub)
# Out:
# a= 8
# b= 8
# add= 0

# %%
a=int(input("a="))
b=int(input("b="))
mul=a*b
print("mul=",mul)
# Out:
# a= 7
# b= 7
# mul= 49

# %%
a=float(input("a="))
b=float(input("b="))
div=a/b
print(" float div=",div)
# Out:
# a= 78.9
# b= 87.6
#  float div= 0.9006849315068495

# %%
a=int(input("a="))
b=int(input("b="))
pow=a**b
print("pow=",pow)
# Out:
# a= 2
# b= 3
# pow= 8

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name=str(input("enter your name:"))
age=int(input("enter your age:"))
sample=str(input("enter your school name:"))              
degree=str(input("enter youor degree:"))
# Out:
# enter your name: remcy
# enter your age: 18
# enter your school name: sairam
# enter youor degree: b.e

# %%
a=int(input("a="))
b=int(input("b="))
floordiv=a//b
print("floor div=",floordiv)
# Out:
# a= 5
# b= 7
# floor div= 0

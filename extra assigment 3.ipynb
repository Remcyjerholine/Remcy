# %%
i=int(input("enter i:"))
if(i==10):
    print("correct")
# Out:
# enter i: 10
# correct

# %%
password=input("enter the password:")
if(password=="HOPE@ai123"):
    print("the password is coreect")
# Out:
# enter the password: HOPE@ai123
# the password is coreect

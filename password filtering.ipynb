# %%
username=input("enter the username:")
if len(username) >12:
    print("the username cannote connatain more than 12 character ")
elif not username.find(" ")==-1 :
    print("the username cannot contain spaces")
elif not username.isalpha():
    print("the username should only user letter not integer")
else:
    print(username)
# Out:
# enter the username: remcy34
# the username should inly user letter not integer
